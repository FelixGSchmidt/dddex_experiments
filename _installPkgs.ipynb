# %%
# Install packages
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install seaborn
# !{sys.executable} -m pip install copy
# !{sys.executable} -m pip install pickle
# !{sys.executable} -m pip install time
# !{sys.executable} -m pip install datetime
# !{sys.executable} -m pip install pyreadr
# !{sys.executable} -m pip install json
# !{sys.executable} -m pip install joblib
# !{sys.executable} -m pip install gurobipy
# !{sys.executable} -m pip install tqdm
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install gluonts
# !{sys.executable} -m pip install xgboost
# !{sys.executable} -m pip install psutil
# !{sys.executable} -m pip install openpyxl
# !{sys.executable} -m pip install scikit-learn-extra
# !{sys.executable} -m pip install lightgbm
# !{sys.executable} -m pip install folium
# !{sys.executable} -m pip install geopy
# !{sys.executable} -m pip install plotnine
# !{sys.executable} -m pip install numba
# Out:
# Collecting numpy
#   Downloading numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 65.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-1.24.1
# Collecting pandas
#   Downloading pandas-1.5.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 62.0 MB/s eta 0:00:0000:0100:01
# Collecting pytz>=2020.1
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 43.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.3 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from pandas) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.5.3 pytz-2022.7.1
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from seaborn) (1.24.1)
# Collecting matplotlib!=3.6.1,>=3.1
#   Downloading matplotlib-3.6.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 61.1 MB/s eta 0:00:0000:0100:01m
# Collecting packaging>=20.0
#   Downloading packaging-23.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.9 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 50.1 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting pyparsing>=2.2.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: pyparsing, pillow, packaging, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.6.3 packaging-23.0 pillow-9.4.0 pyparsing-3.0.9 seaborn-0.12.2
# ERROR: Could not find a version that satisfies the requirement copy (from versions: none)
# ERROR: No matching distribution found for copy
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# ERROR: Could not find a version that satisfies the requirement time (from versions: none)
# ERROR: No matching distribution found for time
# Collecting datetime
#   Downloading DateTime-5.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from datetime) (2022.7.1)
# Collecting zope.interface
#   Using cached zope.interface-5.5.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (261 kB)
# Requirement already satisfied: setuptools in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from zope.interface->datetime) (65.6.3)
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.0 zope.interface-5.5.2
# Collecting pyreadr
#   Using cached pyreadr-0.4.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (364 kB)
# Requirement already satisfied: pandas>=1.2.0 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from pyreadr) (1.5.3)
# Requirement already satisfied: numpy>=1.20.3 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from pandas>=1.2.0->pyreadr) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from pandas>=1.2.0->pyreadr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from pandas>=1.2.0->pyreadr) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pyreadr) (1.16.0)
# Installing collected packages: pyreadr
# Successfully installed pyreadr-0.4.7
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# Collecting joblib
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Installing collected packages: joblib
# Successfully installed joblib-1.2.0
# Collecting gurobipy
#   Using cached gurobipy-10.0.0-cp38-cp38-manylinux2014_x86_64.whl (12.8 MB)
# Installing collected packages: gurobipy
# Successfully installed gurobipy-10.0.0
# Collecting tqdm
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.64.1
# Collecting sklearn
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=f57a5ae5c1169fb12c084226b7559ef0c52d52244abe11e6448beb3b234dd3f2
#   Stored in directory: /home/fesc/.cache/pip/wheels/1c/2f/26/476423e3abcbdc095c9061b4a385339f4d5c4952c036ef8262
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1
# Collecting gluonts
#   Downloading gluonts-0.11.8-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas~=1.0 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from gluonts) (1.5.3)
# Collecting typing-extensions~=4.0
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting pydantic~=1.7
#   Downloading pydantic-1.10.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 19.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm~=4.23 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from gluonts) (4.64.1)
# Collecting toolz~=0.10
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Requirement already satisfied: numpy~=1.16 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from gluonts) (1.24.1)
# Requirement already satisfied: pytz>=2020.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from pandas~=1.0->gluonts) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from pandas~=1.0->gluonts) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas~=1.0->gluonts) (1.16.0)
# Installing collected packages: typing-extensions, toolz, pydantic, gluonts
# Successfully installed gluonts-0.11.8 pydantic-1.10.4 toolz-0.12.0 typing-extensions-4.4.0
# Collecting xgboost
#   Downloading xgboost-1.7.3-py3-none-manylinux2014_x86_64.whl (193.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 MB 15.8 MB/s eta 0:00:0000:0100:01
# Collecting scipy
#   Downloading scipy-1.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 42.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from xgboost) (1.24.1)
# Installing collected packages: scipy, xgboost
# Successfully installed scipy-1.10.0 xgboost-1.7.3
# Collecting psutil
#   Using cached psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
# Installing collected packages: psutil
# Successfully installed psutil-5.9.4
# Collecting openpyxl
#   Using cached openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10
# Collecting scikit-learn-extra
#   Using cached scikit_learn_extra-0.2.0-cp38-cp38-manylinux2010_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=0.19.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from scikit-learn-extra) (1.10.0)
# Collecting scikit-learn>=0.23.0
#   Downloading scikit_learn-1.2.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 66.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.13.3 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from scikit-learn-extra) (1.24.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.2.0)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, scikit-learn, scikit-learn-extra
# Successfully installed scikit-learn-1.2.1 scikit-learn-extra-0.2.0 threadpoolctl-3.1.0
# Collecting lightgbm
#   Downloading lightgbm-3.3.5-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 34.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scikit-learn!=0.22.0 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from lightgbm) (1.2.1)
# Requirement already satisfied: wheel in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: scipy in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from lightgbm) (1.10.0)
# Requirement already satisfied: numpy in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from lightgbm) (1.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (1.2.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.5
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/102.3 kB 6.5 MB/s eta 0:00:00
# Collecting branca>=0.6.0
#   Using cached branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from folium) (1.24.1)
# Collecting requests
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.3 MB/s eta 0:00:00
# Collecting jinja2>=2.9
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from requests->folium) (2022.6.15)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 14.6 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 22.0 MB/s eta 0:00:00
# Installing collected packages: charset-normalizer, urllib3, MarkupSafe, idna, requests, jinja2, branca, folium
# Successfully installed MarkupSafe-2.1.2 branca-0.6.0 charset-normalizer-3.0.1 folium-0.14.0 idna-3.4 jinja2-3.1.2 requests-2.28.2 urllib3-1.26.14
# Collecting geopy
#   Using cached geopy-2.3.0-py3-none-any.whl (119 kB)
# Collecting geographiclib<3,>=1.52
#   Using cached geographiclib-2.0-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.3.0
# Collecting plotnine
#   Using cached plotnine-0.10.1-py3-none-any.whl (1.2 MB)
# Collecting statsmodels>=0.13.2
#   Using cached statsmodels-0.13.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
# Requirement already satisfied: numpy>=1.19.0 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from plotnine) (1.24.1)
# Requirement already satisfied: matplotlib>=3.5.0 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from plotnine) (3.6.3)
# Requirement already satisfied: pandas>=1.3.5 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from plotnine) (1.5.3)
# Collecting mizani>=0.8.1
#   Using cached mizani-0.8.1-py3-none-any.whl (64 kB)
# Requirement already satisfied: scipy>=1.5.0 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from plotnine) (1.10.0)
# Collecting patsy>=0.5.1
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: pillow>=6.2.0 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from matplotlib>=3.5.0->plotnine) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from matplotlib>=3.5.0->plotnine) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from matplotlib>=3.5.0->plotnine) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from matplotlib>=3.5.0->plotnine) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from matplotlib>=3.5.0->plotnine) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from matplotlib>=3.5.0->plotnine) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from matplotlib>=3.5.0->plotnine) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from matplotlib>=3.5.0->plotnine) (23.0)
# Collecting backports.zoneinfo
#   Using cached backports.zoneinfo-0.2.1-cp38-cp38-manylinux1_x86_64.whl (74 kB)
# Collecting palettable
#   Using cached palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from pandas>=1.3.5->plotnine) (2022.7.1)
# Requirement already satisfied: six in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Installing collected packages: palettable, patsy, backports.zoneinfo, statsmodels, mizani, plotnine
# Successfully installed backports.zoneinfo-0.2.1 mizani-0.8.1 palettable-3.3.0 patsy-0.5.3 plotnine-0.10.1 statsmodels-0.13.5
# Collecting numba
#   Using cached numba-0.56.4-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
# Collecting numpy<1.24,>=1.18
#   Using cached numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Using cached llvmlite-0.39.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
# Requirement already satisfied: setuptools in /home/fesc/.conda/envs/dddex/lib/python3.8/site-packages (from numba) (65.6.3)
# Collecting zipp>=0.5
#   Using cached zipp-3.11.0-py3-none-any.whl (6.6 kB)
# Installing collected packages: zipp, numpy, llvmlite, importlib-metadata, numba
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.1
#     Uninstalling numpy-1.24.1:
#       Successfully uninstalled numpy-1.24.1
# Successfully installed importlib-metadata-6.0.0 llvmlite-0.39.1 numba-0.56.4 numpy-1.23.5 zipp-3.11.0

# %%
import sys
# !{sys.executable} -m pip install wandb

# %%
# Update packages
import sys
# !{sys.executable} -m pip install --upgrade pandas

# %%
# Themes
import sys
# !{sys.executable} -m pip install jupyterthemes
# !{sys.executable} -m pip install --upgrade jupyterthemes
# Out:
# Requirement already satisfied: jupyterthemes in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (0.20.0)
# Requirement already satisfied: jupyter-core in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyterthemes) (4.10.0)
# Requirement already satisfied: matplotlib>=1.4.3 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyterthemes) (3.6.2)
# Requirement already satisfied: ipython>=5.4.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyterthemes) (8.4.0)
# Collecting notebook>=5.6.0
#   Using cached notebook-6.5.2-py3-none-any.whl (439 kB)
# Requirement already satisfied: lesscpy>=0.11.2 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyterthemes) (0.15.1)
# Requirement already satisfied: decorator in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.17.2)
# Requirement already satisfied: pexpect>4.3 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (4.8.0)
# Requirement already satisfied: traitlets>=5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.20)
# Requirement already satisfied: backcall in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (65.5.0)
# Requirement already satisfied: stack-data in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: pickleshare in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: matplotlib-inline in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.2)
# Requirement already satisfied: ply in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (9.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.23.5)
# Requirement already satisfied: pyparsing>=2.2.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: ipykernel in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (6.9.1)
# Requirement already satisfied: nest-asyncio>=1.5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.5)
# Requirement already satisfied: jinja2 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (3.1.2)
# Requirement already satisfied: argon2-cffi in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: prometheus-client in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.15.0)
# Requirement already satisfied: nbclassic>=0.4.7 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.4.8)
# Requirement already satisfied: tornado>=6.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (6.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (7.2.2)
# Requirement already satisfied: nbconvert>=5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (5.6.1)
# Requirement already satisfied: terminado>=0.8.3 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.17.1)
# Requirement already satisfied: ipython-genutils in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: nbformat in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (5.7.1)
# Requirement already satisfied: pyzmq>=17 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (23.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.7.1)
# Requirement already satisfied: entrypoints in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.15.6)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: bleach in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (5.0.1)
# Requirement already satisfied: defusedxml in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: testpath in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (2.1.1)
# Requirement already satisfied: fastjsonschema in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.4.1->jupyterthemes) (0.7.0)
# Requirement already satisfied: wcwidth in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: executing in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: pure-eval in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.2.2)
# Requirement already satisfied: asttokens in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (2.0.5)
# Requirement already satisfied: importlib-resources>=1.4.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (5.10.2)
# Requirement already satisfied: attrs>=17.4.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.19.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (1.3.10)
# Requirement already satisfied: anyio>=3.1.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.6.2)
# Requirement already satisfied: websocket-client in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.4.2)
# Requirement already satisfied: cffi>=1.0.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: webencodings in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from bleach->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.3.0)
# Requirement already satisfied: idna>=2.8 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.4)
# Requirement already satisfied: pycparser in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (3.11.0)
# Installing collected packages: notebook
# Successfully installed notebook-6.5.2
# Requirement already satisfied: jupyterthemes in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (0.20.0)
# Requirement already satisfied: ipython>=5.4.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyterthemes) (8.4.0)
# Requirement already satisfied: lesscpy>=0.11.2 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyterthemes) (0.15.1)
# Requirement already satisfied: jupyter-core in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyterthemes) (4.10.0)
# Requirement already satisfied: matplotlib>=1.4.3 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyterthemes) (3.6.2)
# Requirement already satisfied: notebook>=5.6.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyterthemes) (6.5.2)
# Requirement already satisfied: setuptools>=18.5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (65.5.0)
# Requirement already satisfied: jedi>=0.16 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.17.2)
# Requirement already satisfied: decorator in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: pickleshare in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (2.11.2)
# Requirement already satisfied: backcall in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: matplotlib-inline in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (4.8.0)
# Requirement already satisfied: stack-data in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: traitlets>=5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: ply in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: pyparsing>=2.2.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (9.3.0)
# Requirement already satisfied: numpy>=1.19 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.4)
# Requirement already satisfied: argon2-cffi in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (5.6.1)
# Requirement already satisfied: terminado>=0.8.3 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.17.1)
# Requirement already satisfied: prometheus-client in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.15.0)
# Requirement already satisfied: nest-asyncio>=1.5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.5)
# Requirement already satisfied: jupyter-client>=5.3.4 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (7.2.2)
# Requirement already satisfied: ipython-genutils in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: nbformat in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (5.7.1)
# Requirement already satisfied: jinja2 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (6.1)
# Requirement already satisfied: pyzmq>=17 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (23.2.0)
# Requirement already satisfied: ipykernel in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (6.9.1)
# Requirement already satisfied: nbclassic>=0.4.7 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from notebook>=5.6.0->jupyterthemes) (0.4.8)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.7.1)
# Requirement already satisfied: entrypoints in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.15.6)
# Requirement already satisfied: testpath in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.6.0)
# Requirement already satisfied: bleach in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (5.0.1)
# Requirement already satisfied: defusedxml in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (2.1.1)
# Requirement already satisfied: jsonschema>=2.6 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.17.3)
# Requirement already satisfied: fastjsonschema in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.4.1->jupyterthemes) (0.7.0)
# Requirement already satisfied: wcwidth in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: executing in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: pure-eval in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.2.2)
# Requirement already satisfied: asttokens in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (2.0.5)
# Requirement already satisfied: importlib-resources>=1.4.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (5.10.2)
# Requirement already satisfied: attrs>=17.4.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (22.2.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.19.3)
# Requirement already satisfied: anyio>=3.1.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.6.2)
# Requirement already satisfied: websocket-client in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.4.2)
# Requirement already satisfied: cffi>=1.0.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: webencodings in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from bleach->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.3.0)
# Requirement already satisfied: idna>=2.8 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.4)
# Requirement already satisfied: pycparser in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in ./.conda/envs/DDDInventoryControl/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (3.11.0)

# %%
# Themes
import sys
# !{sys.executable} -m pip install tornado==6.1 --force-reinstall
# Out:
# Collecting tornado==6.1
#   Downloading tornado-6.1-cp38-cp38-manylinux2010_x86_64.whl (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.5/427.5 kB 23.4 MB/s eta 0:00:00
# Installing collected packages: tornado
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
# Successfully installed tornado-6.1
